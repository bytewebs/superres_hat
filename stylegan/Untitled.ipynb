# %%
import torch
print(torch.__version__)
# Out:
# 1.7.1

# %%
# !nvcc --version
# Out:
# /bin/bash: nvcc: command not found

# %%
# !python train.py --gpus=4 --batch 32 --snap=1 --resume=lsundog-res256-paper256-kimg100000-noaug.pkl --metrics="none" --augpipe=bg --outdir=./temp_run --data=../../sentinel_dataset/
# Out:
# Training options:
# {
#   "num_gpus": 4,
#   "image_snapshot_ticks": 1,
#   "network_snapshot_ticks": 1,
#   "metrics": [],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset_sentinel.SentinelDataset",
#     "path": "../../sentinel_dataset/",
#     "use_labels": false,
#     "max_size": 167,
#     "xflip": false,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...

# %%
import torch
a = torch.load('lsundog-res256-paper256-kimg100000-noaug.pkl')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 2
#       1 import torch
# ----> 2 a = torch.load('lsundog-res256-paper256-kimg100000-noaug.pkl')
#
# File /project/6075933/ayush12/ENV/lib/python3.8/site-packages/torch/serialization.py:795, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     793     except RuntimeError as e:
#     794         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 795 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File /project/6075933/ayush12/ENV/lib/python3.8/site-packages/torch/serialization.py:1004, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1002 magic_number = pickle_module.load(f, **pickle_load_args)
#    1003 if magic_number != MAGIC_NUMBER:
# ...
