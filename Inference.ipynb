# %%
from inference_utils import *

raster_path = '../sentinel2_AOI5_clip.tif'

# %% [markdown]
# ### Generating Output Raster

# %% [markdown]
# #### Using GLEAN

# %%
chpt_rgb = './ESRGAN-PA/models_test/gen_rgb2_esrgan_pa.pt'
chpt = './RefGLEAN/models_test/gen_band_glean.pt'
generate_raster_glean('./results/aoi5/AOI5_glean.tif', chpt_rgb, chpt, '../sentinel2_AOI5_clip.tif', 2, 2, 5, rgb_model='esrgan_pa', model='glean')

# %% [markdown]
# #### Using Light GLEAN

# %%
chpt_rgb = './ESRGAN-PA/models_test/gen_rgb2_esrgan_pa.pt'
chpt = './LightRefGLEAN/models_test/gen_band_light_glean.pt'
generate_raster_glean('./results/aoi5/AOI5_light_glean.tif', chpt_rgb, chpt, '../sentinel2_AOI5_clip.tif', 2, 2, 5, rgb_model='esrgan_pa', model='light_glean')

# %% [markdown]
# #### Using SenGLEAN

# %%
chpt_rgb = './ESRGAN-PA/models_test/gen_rgb2_esrgan_pa.pt'
chpt = './RefGLEAN/models_test/gen_band_glean.pt'
generate_raster_glean('./results/aoi5/AOI5_glean.tif', chpt_rgb, chpt, '../sentinel2_AOI5_clip.tif', 2, 2, 5, rgb_model='esrgan_pa', model='glean')
